# %% [markdown]
# ## Ejercicio 02 (a)

# %%
import numpy as np
import matplotlib.pyplot as plt

def funcion1(x:float)->float:
    return x
def funcion2(x:float)->float:
    return np.sin(x)

x = np.linspace(-10, 10, 500)
y1 = funcion1(x)
y2 = funcion2(x)
plt.figure(figsize=(5, 4))
plt.plot(x, y1, label='f1(x) = x')
plt.plot(x, y2, label='f2(x) = sin(x)')
ax = plt.gca()
ax.set_ylim([-3, 3])
ax.set_xlim([-3, 3])

plt.title('Gráfica de x y sin(x)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Ejercicio 02 (b)

# %%
def funcion3(x:float)->float:
    return x-2*np.sin(x)

x = np.linspace(-10, 10, 500)
y3 = funcion3(x)
plt.figure(figsize=(5, 4))
plt.plot(x, y3, color='purple', label='f3(x) = x - 2sin(x)')
ax = plt.gca()
ax.set_ylim([-3, 3])
ax.set_xlim([-3, 3])

plt.title('Gráfica de f3(x)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.show()

# %%
def bisection_method(f, a, b, tol):
    if f(a) * f(b) > 0:
        raise ValueError("f(a) y f(b) deben tener signos opuestos")

    iterations = 0
    while (b - a) / 2 > tol:
        puntoMedio = (a + b) / 2
        iterations += 1
        if f(puntoMedio) == 0:
            return puntoMedio, iterations
        elif f(a) * f(puntoMedio) < 0:
            b = puntoMedio
        else:
            a = puntoMedio

    return (a + b) / 2, iterations

# Definimos la función
def f(x):
    return x - 2*np.sin(x)

# Definimos los intervalos y la tolerancia
intervalos = [(1,2)]
tolerancia = 0.00001

# Calculamos las raíces para cada intervalo
raices = []
for interval in intervalos:
    raiz, iteraciones = bisection_method(f, interval[0], interval[1], tolerancia)
    raices.append(raiz)
    print(f"Raíz encontrada: {raiz}, Iteraciones: {iteraciones}")

#print(raices[0])
# Out:
# Raíz encontrada: 1.8955001831054688, Iteraciones: 16
# 1.8955001831054688
